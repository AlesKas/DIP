# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from math import sqrt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
ping_data = pd.read_csv('./data/ping_data.csv')
ping_data_wireless = pd.read_csv('./data/ping_data_rp59adf374.csv')
ping_data_ethernet = pd.read_csv('./data/ping_data_rp829c7e0e.csv')

# %%
series = pd.Series(ping_data_wireless['remote_avg'])
series.diff().fillna(series).plot(figsize=(16, 7))
# Out:
# <Axes: >

# %%
series = pd.Series(ping_data_wireless['local_avg'])
series.diff().fillna(series).plot(figsize=(16, 7))
# Out:
# <Axes: >

# %%
series = pd.Series(ping_data_ethernet['local_avg'])
series.diff().fillna(series).plot(figsize=(16, 7))
# Out:
# <Axes: >

# %%
series = pd.Series(ping_data_ethernet['remote_avg'])
series.diff().fillna(series).plot(figsize=(16, 7))
# Out:
# <Axes: >
